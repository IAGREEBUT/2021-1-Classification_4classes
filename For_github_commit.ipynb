# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
cd '/gdrive/MyDrive/2021-1-Mentor(CNN)/2021-1-Classification_4classes/'

# %%
# !echo "# 2021-1-Classification_4classes" >> README.md
# !git init
# !git config --global user.email "dldbwjd24@ewhain.net"
# !git config --global user.name "IAGREEBUT"
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://IAGREEBUT:dldbwjd0308!@github.com/IAGREEBUT/2021-1-Classification_4classes.git
# !git push -u origin main

# %%
# !git config --global user.email "dldbwjd24@ewhain.net"
# !git config --global user.name "IAGREEBUT"
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://IAGREEBUT:dldbwjd0308!@github.com/IAGREEBUT/2021-1-Classification_4classes.git
# !git push -u origin main

# %%
# !git branch -M main
# !git remote add origin https://IAGREEBUT:dldbwjd0308!@github.com/IAGREEBUT/2021-1-Classification_4classes.git
# !git push -u origin main

# %%
# !git init

# %%
# !git config --global user.email "dldbwjd24@ewhain.net"
# !git config --global user.name "IAGREEBUT"

# %%
# !git add .

# %%
# !git commit -m "setup"

# %%
# !git remote add origin https://IAGREEBUT:dldbwjd0308!@github.com/IAGREEBUT/2021-1-Classification_4classes.git

# %%
#!git remote rm origin

# %%
#!git pull origin master

# %%
# !git pull origin main

# %%
# !git push -u origin main
